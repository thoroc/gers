# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %matplotlib inline

import pandas as pd
import ipywidgets as widgets
import numpy as np

from matplotlib import pyplot as plt
from pathlib import Path

data_path = Path('data', 'clean')

# %%
# loading the data
data_file = Path(data_path, 'net_fiscal_balance.csv')
balance = pd.read_csv(data_file)

# %%
# create an array with the delta value between row_index_x and row_index_y

def delta(df, row_index_x, row_index_y, label='Difference'):
    d = [label]
    for i in range(1, len(df.columns)):
        d.append(abs(df.iloc[row_index_x, i] - df.iloc[row_index_y, i]))
    
    return d

# %% [markdown]
# ## Net Fiscal Balance in Value (£ million)

# %%
# only the revenue in value
values = balance[0:3].copy().reset_index(drop=True)

# swaping indexes
values_t = values.set_index('Period').transpose()


plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (£ million)', color='black')
values_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %% [markdown]
# ### Excluding North Sea

# %%
# only the revenue in value
values_ens = balance.take([0,2]).copy().reset_index(drop=True)

# And add a delta between them
values_ens.loc[len(values_ens.index)] = delta(values_ens, 0, 1, 'Difference (£ million)')

# swaping indexes
values_ens_t = values_ens.set_index('Period').transpose()


plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (£ million)', color='black')
values_ens_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %% [markdown]
# ### Including North Sea

# %%
# only the revenue in value
values_ins = balance.take([1,2]).copy().reset_index(drop=True)

# And add a delta between them
values_ins.loc[len(values_ins.index)] = delta(values_ins, 0, 1, 'Difference (£ million)')

# swaping indexes
values_ins_t = values_ins.set_index('Period').transpose()

plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (£ million)', color='black')
values_ins_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %% [markdown]
# ## Net Fiscal Balance in % of GDP

# %%
# only the revenue in Percent of the UK revenue
percent = balance[3:].copy().reset_index(drop=True)
percent_t = percent.set_index('Period').transpose()

plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (% of GDP)', color='black')
percent_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %% [markdown]
# ### Excluding North Sea

# %%
# only the revenue in value
percent_ens = balance.take([3,5]).copy().reset_index(drop=True)

# And add a delta between them
percent_ens.loc[len(percent_ens.index)] = delta(percent_ens, 0, 1, 'Difference (£ million)')

# swaping indexes
percent_ens_t = percent_ens.set_index('Period').transpose()

plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (% GPD)', color='black')
percent_ens_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %% [markdown]
# ### Including North Sea

# %%
# only the revenue in value
percent_ins = balance.take([4,5]).copy().reset_index(drop=True)

# And add a delta between them
percent_ins.loc[len(percent_ins.index)] = delta(percent_ins, 0, 1, 'Difference (£ million)')

# swaping indexes
percent_ins_t = percent_ins.set_index('Period').transpose()

plt.rcParams['figure.figsize'] = (10,5)

f = plt.figure()
plt.title('Net Fiscal Balance (% GPD)', color='black')
percent_ins_t.plot(ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()
